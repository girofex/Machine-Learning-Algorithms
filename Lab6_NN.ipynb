# %% [markdown]
# # Lab. 6 - A glimpse of Neural Networks

# %%
import numpy as np
from scipy.interpolate import griddata
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPool2D

from keras.utils import to_categorical

import matplotlib.pyplot as plt

# %% [markdown]
# ## Instructions on using Keras
#
# Models in Keras are defined as a sequence of layers.
#
# We create a [Sequential](https://www.tensorflow.org/api_docs/python/tf/keras/Sequential) object which holds multiple layers executed one by one, and add layers to the object until we have formed the architecture.
#
# To create the first layer, you need to know the right number of input features. You can specify this by using the `input_dim` argument.
#
# The things to choose when defining the architecture are many:
#  - number of layers
#  - type of layers
#  - size of layers
#  - type of non-linearity
#  - whether or not to add regularization
#
# Here we will use only fully-connected (dense) layers, so the type of layer is fixed. Fully connected layers are defined using the [Dense](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Dense) class, which takes as parameters the number of neurons (which is the **dimension of the output**).
#
# The activation functions are used after each dense layer. You can choose the activation functions for hidden layers yourself, a common choice being the [ReLU](https://www.tensorflow.org/api_docs/python/tf/keras/activations/relu) activation. But for the last layer, the activation must reflect the range of the outputs.
#
# Since we will work with binary classification problem, the output should be between 0 and 1, which is then easy to map to any given class. To ensure this we can use the [Sigmoid](https://www.tensorflow.org/api_docs/python/tf/keras/activations/sigmoid) activation.
#
#
# After having created a model you need to **compile** it. During the compilation phase you must specify some parameters related to how the model will be optimized:
#  - The `optimizer`. For the following exercise you should use [SGD](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/SGD), initialized with some learning rate (instructions on how to choose it follow).
#  - The `loss` function. For binary classification you can use the [cross-entropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/BinaryCrossentropy) loss.
#  - A list of `metrics`: common error functions which you want keras to report at each training epoch.
#
# Then you may actually train the model by calling **fit**. The fit function takes as input the training data, and some more parameters related to the training process:
#  - `epochs` : the number of epochs to train for
#  - `batch_size` : the size of mini-batches. A high batch-size will speed up computations but may make training unstable.
#
# Other useful functions are `model.predict` which runs the model's forward pass to predict on new samples, and `model.evaluate` which is similar to `predict` but instead of giving predictions as output, it simply computes some metrics.

# %%
def generate_2d_cls_data(n, sigma_noise):
    n_cls = n // 2

    theta = np.random.randn(n_cls) * 2 * np.pi
    cls1 = np.stack([np.cos(theta) * 2, np.sin(theta) * 2], axis=1)
    cls2 = np.random.randn(n_cls, 2) * 0.5

    cls1 += np.random.randn(cls1.shape[0], 2) * sigma_noise * 3
    cls2 += np.random.randn(cls2.shape[0], 2) * sigma_noise

    X = np.concatenate([cls1, cls2], axis=0)
    y = np.concatenate([np.zeros(n_cls), np.ones(n_cls)], axis=0)

    return X, y

# %%
def separatingFLR(data, labels, predictions, model):
    fig, ax = plt.subplots()

    num_grid_points = 100
    xi = np.linspace(data[:, 0].min(), data[:, 0].max(), num_grid_points)
    yi = np.linspace(data[:, 1].min(), data[:, 1].max(), num_grid_points)
    gdata = np.stack([xi, yi], 1)
    X, Y = np.meshgrid(xi,yi)
    pred_grid = model.predict(
        np.stack([X.reshape(-1), Y.reshape(-1)], axis=1)
    ).reshape(num_grid_points, num_grid_points)

    ax.contour(xi, yi, pred_grid, 15, linewidths=2, colors='k', levels=[0.5])
    # plot data points.
    ax.scatter(data[:,0], data[:,1], c=labels.ravel(), marker='o', s=100, zorder=10, alpha=0.8)
    ax.set_xlim(data[:,0].min(), data[:,0].max())
    ax.set_ylim(data[:,1].min(), data[:,1].max())
    return fig, ax

# %%
def calc_err(predicted, observed):
    predicted = predicted.ravel()
    observed = observed.ravel()
    threshold_preds = predicted.copy()
    threshold_preds[predicted < 0.5] = 0
    threshold_preds[predicted >= 0.5] = 1
    return np.mean(threshold_preds != observed)

# %% [markdown]
# ### Synthetic Example

# %% [markdown]
# #### Generating the train and test sets
#
# Note that with neural nets, the labels for binary classification should be 0 and +1.

# %%
# put your code here
Xtr, Ytr = generate_2d_cls_data(100, 0.3)
Xte, Yte = generate_2d_cls_data(100, 0.3)

# %%
# Build your first model by creating a Sequential object and then adding 2 Dense layers:
model = Sequential()
model.add(Dense(4, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # This is the last layer, it should have 1 neuron and the sigmoid activation
model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.05), # Algorithm used for optimization
    loss='binary_crossentropy',                         # The loss function
    metrics=['accuracy'],                               # Metrics to evaluate the goodness of predictions
)
history = model.fit(
    Xtr, Ytr,                       # Training data
    epochs=600,                     # Number of training epochs
    batch_size=10,                  # Train using mini-batches of 10 samples each
    validation_split=0.2,           # Split the data using 80% to train and 20% for validation
)

# Predict and calculate errors
train_preds = model.predict(Xtr)
test_preds = model.predict(Xte)
train_err = calc_err(train_preds, Ytr)
test_err = calc_err(test_preds, Yte)
print("Training error: %.2f%%, Test error: %.2f%%" % (train_err * 100, test_err * 100))
# Out:
# Epoch 1/600
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3400 - loss: 0.8690 - val_accuracy: 0.2500 - val_loss: 0.6985
# Epoch 2/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2955 - loss: 0.7736 - val_accuracy: 0.1000 - val_loss: 0.7494
# Epoch 3/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3816 - loss: 0.7288 - val_accuracy: 0.0000e+00 - val_loss: 0.7878
# Epoch 4/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6127 - loss: 0.6788 - val_accuracy: 0.0000e+00 - val_loss: 0.8140
# Epoch 5/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6994 - loss: 0.6394 - val_accuracy: 0.0000e+00 - val_loss: 0.8328
# Epoch 6/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6420 - loss: 0.6550 - val_accuracy: 0.0000e+00 - val_loss: 0.8476
# Epoch 7/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6304 - loss: 0.6401 - val_accuracy: 0.0000e+00 - val_loss: 0.8550
# Epoch 8/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6254 - loss: 0.6410 - val_accuracy: 0.0000e+00 - val_loss: 0.8605
# Epoch 9/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6396 - loss: 0.6272 - val_accuracy: 0.0000e+00 - val_loss: 0.8643
# Epoch 10/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6488 - loss: 0.6008 - val_accuracy: 0.0000e+00 - val_loss: 0.8666
# Epoch 11/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6321 - loss: 0.6256 - val_accuracy: 0.0000e+00 - val_loss: 0.8688
# Epoch 12/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5960 - loss: 0.6353 - val_accuracy: 0.0000e+00 - val_loss: 0.8702
# Epoch 13/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6015 - loss: 0.6175 - val_accuracy: 0.0000e+00 - val_loss: 0.8700
# Epoch 14/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5877 - loss: 0.6311 - val_accuracy: 0.0000e+00 - val_loss: 0.8699
# Epoch 15/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5790 - loss: 0.6275 - val_accuracy: 0.0000e+00 - val_loss: 0.8693
# Epoch 16/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6878 - loss: 0.5825 - val_accuracy: 0.0000e+00 - val_loss: 0.8668
# Epoch 17/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5889 - loss: 0.6176 - val_accuracy: 0.0000e+00 - val_loss: 0.8653
# Epoch 18/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6081 - loss: 0.5867 - val_accuracy: 0.0000e+00 - val_loss: 0.8627
# Epoch 19/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6465 - loss: 0.5947 - val_accuracy: 0.0000e+00 - val_loss: 0.8595
# Epoch 20/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6046 - loss: 0.6161 - val_accuracy: 0.0000e+00 - val_loss: 0.8574
# Epoch 21/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5374 - loss: 0.6442 - val_accuracy: 0.0000e+00 - val_loss: 0.8564
# Epoch 22/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6808 - loss: 0.5656 - val_accuracy: 0.0000e+00 - val_loss: 0.8521
# Epoch 23/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6605 - loss: 0.5666 - val_accuracy: 0.0000e+00 - val_loss: 0.8482
# Epoch 24/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5794 - loss: 0.6025 - val_accuracy: 0.0000e+00 - val_loss: 0.8461
# Epoch 25/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6278 - loss: 0.5737 - val_accuracy: 0.0000e+00 - val_loss: 0.8429
# Epoch 26/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6760 - loss: 0.5561 - val_accuracy: 0.0000e+00 - val_loss: 0.8389
# Epoch 27/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6638 - loss: 0.5497 - val_accuracy: 0.0000e+00 - val_loss: 0.8349
# Epoch 28/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5553 - loss: 0.5840 - val_accuracy: 0.0000e+00 - val_loss: 0.8321
# Epoch 29/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6008 - loss: 0.5422 - val_accuracy: 0.0000e+00 - val_loss: 0.8276
# Epoch 30/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6263 - loss: 0.5786 - val_accuracy: 0.0000e+00 - val_loss: 0.8221
# Epoch 31/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5907 - loss: 0.5763 - val_accuracy: 0.0000e+00 - val_loss: 0.8183
# Epoch 32/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6252 - loss: 0.5865 - val_accuracy: 0.0000e+00 - val_loss: 0.8141
# Epoch 33/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6517 - loss: 0.5408 - val_accuracy: 0.0000e+00 - val_loss: 0.8096
# Epoch 34/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6083 - loss: 0.5502 - val_accuracy: 0.1000 - val_loss: 0.8048
# Epoch 35/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6359 - loss: 0.5657 - val_accuracy: 0.1000 - val_loss: 0.8006
# Epoch 36/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6988 - loss: 0.5194 - val_accuracy: 0.1000 - val_loss: 0.7956
# Epoch 37/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7910 - loss: 0.5086 - val_accuracy: 0.1000 - val_loss: 0.7902
# Epoch 38/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7614 - loss: 0.5267 - val_accuracy: 0.2000 - val_loss: 0.7859
# Epoch 39/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8142 - loss: 0.4836 - val_accuracy: 0.2500 - val_loss: 0.7798
# Epoch 40/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7992 - loss: 0.4806 - val_accuracy: 0.3000 - val_loss: 0.7748
# Epoch 41/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8634 - loss: 0.5010 - val_accuracy: 0.3500 - val_loss: 0.7715
# Epoch 42/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8628 - loss: 0.4926 - val_accuracy: 0.4000 - val_loss: 0.7701
# Epoch 43/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8480 - loss: 0.4819 - val_accuracy: 0.4500 - val_loss: 0.7654
# Epoch 44/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8285 - loss: 0.5279 - val_accuracy: 0.4500 - val_loss: 0.7619
# Epoch 45/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8119 - loss: 0.4876 - val_accuracy: 0.4500 - val_loss: 0.7585
# Epoch 46/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8280 - loss: 0.5142 - val_accuracy: 0.5000 - val_loss: 0.7573
# Epoch 47/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7930 - loss: 0.5011 - val_accuracy: 0.5500 - val_loss: 0.7541
# Epoch 48/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8241 - loss: 0.4779 - val_accuracy: 0.6500 - val_loss: 0.7468
# Epoch 49/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8597 - loss: 0.4635 - val_accuracy: 0.7000 - val_loss: 0.7419
# Epoch 50/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8151 - loss: 0.5082 - val_accuracy: 0.7000 - val_loss: 0.7385
# Epoch 51/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8795 - loss: 0.4528 - val_accuracy: 0.7000 - val_loss: 0.7361
# Epoch 52/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8302 - loss: 0.4591 - val_accuracy: 0.7000 - val_loss: 0.7310
# Epoch 53/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9087 - loss: 0.4437 - val_accuracy: 0.7000 - val_loss: 0.7286
# Epoch 54/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8616 - loss: 0.4483 - val_accuracy: 0.7000 - val_loss: 0.7221
# Epoch 55/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8820 - loss: 0.5077 - val_accuracy: 0.7000 - val_loss: 0.7206
# Epoch 56/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9198 - loss: 0.4790 - val_accuracy: 0.7000 - val_loss: 0.7174
# Epoch 57/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9024 - loss: 0.4091 - val_accuracy: 0.7000 - val_loss: 0.7113
# Epoch 58/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9065 - loss: 0.4566 - val_accuracy: 0.7000 - val_loss: 0.7105
# Epoch 59/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9243 - loss: 0.4125 - val_accuracy: 0.7000 - val_loss: 0.7059
# Epoch 60/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9049 - loss: 0.4634 - val_accuracy: 0.7000 - val_loss: 0.7034
# Epoch 61/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8883 - loss: 0.4359 - val_accuracy: 0.7000 - val_loss: 0.7007
# Epoch 62/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9133 - loss: 0.4342 - val_accuracy: 0.7000 - val_loss: 0.6961
# Epoch 63/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9281 - loss: 0.4026 - val_accuracy: 0.7000 - val_loss: 0.6909
# Epoch 64/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9243 - loss: 0.4089 - val_accuracy: 0.7000 - val_loss: 0.6878
# Epoch 65/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9507 - loss: 0.4107 - val_accuracy: 0.7000 - val_loss: 0.6855
# Epoch 66/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8778 - loss: 0.4491 - val_accuracy: 0.7000 - val_loss: 0.6868
# Epoch 67/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9074 - loss: 0.4380 - val_accuracy: 0.7000 - val_loss: 0.6842
# Epoch 68/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9450 - loss: 0.3766 - val_accuracy: 0.7000 - val_loss: 0.6813
# Epoch 69/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9065 - loss: 0.3898 - val_accuracy: 0.7000 - val_loss: 0.6756
# Epoch 70/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9289 - loss: 0.3936 - val_accuracy: 0.7000 - val_loss: 0.6692
# Epoch 71/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9092 - loss: 0.3825 - val_accuracy: 0.7000 - val_loss: 0.6663
# Epoch 72/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9044 - loss: 0.3761 - val_accuracy: 0.7000 - val_loss: 0.6661
# Epoch 73/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9038 - loss: 0.3695 - val_accuracy: 0.7500 - val_loss: 0.6654
# Epoch 74/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8759 - loss: 0.3786 - val_accuracy: 0.7500 - val_loss: 0.6607
# Epoch 75/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9178 - loss: 0.3712 - val_accuracy: 0.7500 - val_loss: 0.6614
# Epoch 76/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9102 - loss: 0.3609 - val_accuracy: 0.7500 - val_loss: 0.6567
# Epoch 77/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9337 - loss: 0.3765 - val_accuracy: 0.7500 - val_loss: 0.6562
# Epoch 78/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9106 - loss: 0.3600 - val_accuracy: 0.7500 - val_loss: 0.6565
# Epoch 79/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9006 - loss: 0.3893 - val_accuracy: 0.7500 - val_loss: 0.6542
# Epoch 80/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9300 - loss: 0.3240 - val_accuracy: 0.7500 - val_loss: 0.6528
# Epoch 81/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9161 - loss: 0.3731 - val_accuracy: 0.7500 - val_loss: 0.6543
# Epoch 82/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9192 - loss: 0.3479 - val_accuracy: 0.7500 - val_loss: 0.6547
# Epoch 83/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9003 - loss: 0.3446 - val_accuracy: 0.7500 - val_loss: 0.6548
# Epoch 84/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9225 - loss: 0.3118 - val_accuracy: 0.7500 - val_loss: 0.6510
# Epoch 85/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9270 - loss: 0.3418 - val_accuracy: 0.7500 - val_loss: 0.6476
# Epoch 86/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8943 - loss: 0.3595 - val_accuracy: 0.7500 - val_loss: 0.6527
# Epoch 87/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9184 - loss: 0.3613 - val_accuracy: 0.7500 - val_loss: 0.6521
# Epoch 88/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9173 - loss: 0.3385 - val_accuracy: 0.7500 - val_loss: 0.6512
# Epoch 89/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8647 - loss: 0.3822 - val_accuracy: 0.7500 - val_loss: 0.6509
# Epoch 90/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8486 - loss: 0.3831 - val_accuracy: 0.7500 - val_loss: 0.6497
# Epoch 91/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8700 - loss: 0.3584 - val_accuracy: 0.7500 - val_loss: 0.6472
# Epoch 92/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8973 - loss: 0.3702 - val_accuracy: 0.7500 - val_loss: 0.6460
# Epoch 93/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8815 - loss: 0.3980 - val_accuracy: 0.7500 - val_loss: 0.6391
# Epoch 94/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8951 - loss: 0.3418 - val_accuracy: 0.7500 - val_loss: 0.6334
# Epoch 95/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9226 - loss: 0.3095 - val_accuracy: 0.7500 - val_loss: 0.6302
# Epoch 96/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8760 - loss: 0.3474 - val_accuracy: 0.7500 - val_loss: 0.6373
# Epoch 97/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8943 - loss: 0.3627 - val_accuracy: 0.7500 - val_loss: 0.6384
# Epoch 98/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9061 - loss: 0.3303 - val_accuracy: 0.7500 - val_loss: 0.6342
# Epoch 99/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8836 - loss: 0.3622 - val_accuracy: 0.7500 - val_loss: 0.6305
# Epoch 100/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9231 - loss: 0.2881 - val_accuracy: 0.7500 - val_loss: 0.6357
# Epoch 101/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9020 - loss: 0.3333 - val_accuracy: 0.7500 - val_loss: 0.6340
# Epoch 102/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9186 - loss: 0.3165 - val_accuracy: 0.7500 - val_loss: 0.6352
# Epoch 103/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9278 - loss: 0.3391 - val_accuracy: 0.7500 - val_loss: 0.6305
# Epoch 104/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8867 - loss: 0.3276 - val_accuracy: 0.7500 - val_loss: 0.6286
# Epoch 105/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9243 - loss: 0.3575 - val_accuracy: 0.7500 - val_loss: 0.6303
# Epoch 106/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8925 - loss: 0.3544 - val_accuracy: 0.7500 - val_loss: 0.6271
# Epoch 107/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9067 - loss: 0.3304 - val_accuracy: 0.7500 - val_loss: 0.6315
# Epoch 108/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8811 - loss: 0.3855 - val_accuracy: 0.7500 - val_loss: 0.6347
# Epoch 109/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9270 - loss: 0.2915 - val_accuracy: 0.8000 - val_loss: 0.6309
# Epoch 110/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8607 - loss: 0.3417 - val_accuracy: 0.8000 - val_loss: 0.6283
# Epoch 111/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9417 - loss: 0.2535 - val_accuracy: 0.8000 - val_loss: 0.6293
# Epoch 112/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8419 - loss: 0.3505 - val_accuracy: 0.8000 - val_loss: 0.6344
# Epoch 113/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8644 - loss: 0.3372 - val_accuracy: 0.8000 - val_loss: 0.6285
# Epoch 114/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8641 - loss: 0.3636 - val_accuracy: 0.8000 - val_loss: 0.6302
# Epoch 115/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9021 - loss: 0.3341 - val_accuracy: 0.8000 - val_loss: 0.6344
# Epoch 116/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8707 - loss: 0.3143 - val_accuracy: 0.8000 - val_loss: 0.6314
# Epoch 117/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9003 - loss: 0.2976 - val_accuracy: 0.8000 - val_loss: 0.6344
# Epoch 118/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9016 - loss: 0.3085 - val_accuracy: 0.8000 - val_loss: 0.6297
# Epoch 119/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8911 - loss: 0.3108 - val_accuracy: 0.8000 - val_loss: 0.6404
# Epoch 120/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8934 - loss: 0.3138 - val_accuracy: 0.8000 - val_loss: 0.6356
# Epoch 121/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9210 - loss: 0.2917 - val_accuracy: 0.8000 - val_loss: 0.6346
# Epoch 122/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9224 - loss: 0.2602 - val_accuracy: 0.8000 - val_loss: 0.6379
# Epoch 123/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8804 - loss: 0.3035 - val_accuracy: 0.8000 - val_loss: 0.6317
# Epoch 124/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9016 - loss: 0.3042 - val_accuracy: 0.8000 - val_loss: 0.6390
# Epoch 125/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9075 - loss: 0.3282 - val_accuracy: 0.8000 - val_loss: 0.6413
# Epoch 126/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9004 - loss: 0.3475 - val_accuracy: 0.8000 - val_loss: 0.6424
# Epoch 127/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9192 - loss: 0.3208 - val_accuracy: 0.8000 - val_loss: 0.6394
# Epoch 128/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9424 - loss: 0.2806 - val_accuracy: 0.8000 - val_loss: 0.6443
# Epoch 129/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9154 - loss: 0.3330 - val_accuracy: 0.8000 - val_loss: 0.6427
# Epoch 130/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9246 - loss: 0.3019 - val_accuracy: 0.8000 - val_loss: 0.6442
# Epoch 131/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8970 - loss: 0.3451 - val_accuracy: 0.8000 - val_loss: 0.6417
# Epoch 132/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9247 - loss: 0.2695 - val_accuracy: 0.8000 - val_loss: 0.6469
# Epoch 133/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9050 - loss: 0.3336 - val_accuracy: 0.8000 - val_loss: 0.6458
# Epoch 134/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9037 - loss: 0.3543 - val_accuracy: 0.8000 - val_loss: 0.6528
# Epoch 135/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9136 - loss: 0.2840 - val_accuracy: 0.8000 - val_loss: 0.6498
# Epoch 136/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9461 - loss: 0.2807 - val_accuracy: 0.8000 - val_loss: 0.6470
# Epoch 137/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9252 - loss: 0.2658 - val_accuracy: 0.8000 - val_loss: 0.6398
# Epoch 138/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9331 - loss: 0.2576 - val_accuracy: 0.8000 - val_loss: 0.6376
# Epoch 139/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9298 - loss: 0.2769 - val_accuracy: 0.8000 - val_loss: 0.6378
# Epoch 140/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9121 - loss: 0.2978 - val_accuracy: 0.8000 - val_loss: 0.6442
# Epoch 141/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9272 - loss: 0.2644 - val_accuracy: 0.8000 - val_loss: 0.6408
# Epoch 142/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8979 - loss: 0.3349 - val_accuracy: 0.8000 - val_loss: 0.6381
# Epoch 143/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9045 - loss: 0.2850 - val_accuracy: 0.8000 - val_loss: 0.6489
# Epoch 144/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9047 - loss: 0.2891 - val_accuracy: 0.8000 - val_loss: 0.6398
# Epoch 145/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9486 - loss: 0.2830 - val_accuracy: 0.8000 - val_loss: 0.6481
# Epoch 146/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9242 - loss: 0.2803 - val_accuracy: 0.8000 - val_loss: 0.6498
# Epoch 147/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9105 - loss: 0.2990 - val_accuracy: 0.8000 - val_loss: 0.6489
# Epoch 148/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9593 - loss: 0.2471 - val_accuracy: 0.8000 - val_loss: 0.6531
# Epoch 149/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9317 - loss: 0.2774 - val_accuracy: 0.8000 - val_loss: 0.6529
# Epoch 150/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9676 - loss: 0.2481 - val_accuracy: 0.8000 - val_loss: 0.6472
# Epoch 151/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9131 - loss: 0.2603 - val_accuracy: 0.8000 - val_loss: 0.6462
# Epoch 152/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9223 - loss: 0.2991 - val_accuracy: 0.8000 - val_loss: 0.6476
# Epoch 153/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8867 - loss: 0.3135 - val_accuracy: 0.8000 - val_loss: 0.6425
# Epoch 154/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8709 - loss: 0.3141 - val_accuracy: 0.8000 - val_loss: 0.6477
# Epoch 155/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9143 - loss: 0.2706 - val_accuracy: 0.8000 - val_loss: 0.6549
# Epoch 156/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9419 - loss: 0.2648 - val_accuracy: 0.8000 - val_loss: 0.6585
# Epoch 157/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9155 - loss: 0.2696 - val_accuracy: 0.8000 - val_loss: 0.6572
# Epoch 158/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9220 - loss: 0.2853 - val_accuracy: 0.8000 - val_loss: 0.6622
# Epoch 159/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9052 - loss: 0.3017 - val_accuracy: 0.8000 - val_loss: 0.6598
# Epoch 160/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9292 - loss: 0.2578 - val_accuracy: 0.8000 - val_loss: 0.6654
# Epoch 161/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8865 - loss: 0.3159 - val_accuracy: 0.8000 - val_loss: 0.6656
# Epoch 162/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8827 - loss: 0.3273 - val_accuracy: 0.8000 - val_loss: 0.6591
# Epoch 163/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8946 - loss: 0.3193 - val_accuracy: 0.8000 - val_loss: 0.6654
# Epoch 164/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9110 - loss: 0.2829 - val_accuracy: 0.8000 - val_loss: 0.6725
# Epoch 165/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9217 - loss: 0.2432 - val_accuracy: 0.8000 - val_loss: 0.6628
# Epoch 166/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9280 - loss: 0.2571 - val_accuracy: 0.8000 - val_loss: 0.6591
# Epoch 167/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9203 - loss: 0.2553 - val_accuracy: 0.8000 - val_loss: 0.6725
# Epoch 168/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9153 - loss: 0.2837 - val_accuracy: 0.8000 - val_loss: 0.6624
# Epoch 169/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9130 - loss: 0.2443 - val_accuracy: 0.8000 - val_loss: 0.6650
# Epoch 170/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9079 - loss: 0.2561 - val_accuracy: 0.8000 - val_loss: 0.6555
# Epoch 171/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9108 - loss: 0.2514 - val_accuracy: 0.8000 - val_loss: 0.6624
# Epoch 172/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9571 - loss: 0.2230 - val_accuracy: 0.8000 - val_loss: 0.6537
# Epoch 173/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9093 - loss: 0.2807 - val_accuracy: 0.8000 - val_loss: 0.6655
# Epoch 174/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9288 - loss: 0.2573 - val_accuracy: 0.8000 - val_loss: 0.6744
# Epoch 175/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9326 - loss: 0.2521 - val_accuracy: 0.8000 - val_loss: 0.6838
# Epoch 176/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9024 - loss: 0.2977 - val_accuracy: 0.8000 - val_loss: 0.6801
# Epoch 177/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9062 - loss: 0.2522 - val_accuracy: 0.8000 - val_loss: 0.6803
# Epoch 178/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9509 - loss: 0.2519 - val_accuracy: 0.8000 - val_loss: 0.6808
# Epoch 179/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9369 - loss: 0.2484 - val_accuracy: 0.8000 - val_loss: 0.6849
# Epoch 180/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9352 - loss: 0.2378 - val_accuracy: 0.8000 - val_loss: 0.6778
# Epoch 181/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9419 - loss: 0.2332 - val_accuracy: 0.8000 - val_loss: 0.6742
# Epoch 182/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9486 - loss: 0.2259 - val_accuracy: 0.8000 - val_loss: 0.6780
# Epoch 183/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8929 - loss: 0.2978 - val_accuracy: 0.8000 - val_loss: 0.6759
# Epoch 184/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9108 - loss: 0.2738 - val_accuracy: 0.8000 - val_loss: 0.6874
# Epoch 185/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8905 - loss: 0.2797 - val_accuracy: 0.8000 - val_loss: 0.6752
# Epoch 186/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9165 - loss: 0.2593 - val_accuracy: 0.8000 - val_loss: 0.6800
# Epoch 187/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9157 - loss: 0.2754 - val_accuracy: 0.8000 - val_loss: 0.6737
# Epoch 188/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9013 - loss: 0.2682 - val_accuracy: 0.8000 - val_loss: 0.6748
# Epoch 189/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9317 - loss: 0.2799 - val_accuracy: 0.8000 - val_loss: 0.6763
# Epoch 190/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9407 - loss: 0.2335 - val_accuracy: 0.8000 - val_loss: 0.6825
# Epoch 191/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9313 - loss: 0.2414 - val_accuracy: 0.8000 - val_loss: 0.6908
# Epoch 192/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9611 - loss: 0.2087 - val_accuracy: 0.8000 - val_loss: 0.6843
# Epoch 193/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9474 - loss: 0.1961 - val_accuracy: 0.8000 - val_loss: 0.6863
# Epoch 194/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9292 - loss: 0.2106 - val_accuracy: 0.8000 - val_loss: 0.6817
# Epoch 195/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9199 - loss: 0.2312 - val_accuracy: 0.8000 - val_loss: 0.6883
# Epoch 196/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8957 - loss: 0.2852 - val_accuracy: 0.8000 - val_loss: 0.6909
# Epoch 197/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9481 - loss: 0.2264 - val_accuracy: 0.8000 - val_loss: 0.6878
# Epoch 198/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9645 - loss: 0.1861 - val_accuracy: 0.8000 - val_loss: 0.7047
# Epoch 199/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9601 - loss: 0.1850 - val_accuracy: 0.8000 - val_loss: 0.7078
# Epoch 200/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9019 - loss: 0.2788 - val_accuracy: 0.8000 - val_loss: 0.6979
# Epoch 201/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9381 - loss: 0.2299 - val_accuracy: 0.8000 - val_loss: 0.7026
# Epoch 202/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9110 - loss: 0.2706 - val_accuracy: 0.8000 - val_loss: 0.6913
# Epoch 203/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9220 - loss: 0.2765 - val_accuracy: 0.8000 - val_loss: 0.7075
# Epoch 204/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9517 - loss: 0.2030 - val_accuracy: 0.8000 - val_loss: 0.7126
# Epoch 205/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9453 - loss: 0.2486 - val_accuracy: 0.8000 - val_loss: 0.7091
# Epoch 206/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9083 - loss: 0.2689 - val_accuracy: 0.8000 - val_loss: 0.7118
# Epoch 207/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9210 - loss: 0.2232 - val_accuracy: 0.8000 - val_loss: 0.7073
# Epoch 208/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9230 - loss: 0.2700 - val_accuracy: 0.8000 - val_loss: 0.6977
# Epoch 209/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9382 - loss: 0.2254 - val_accuracy: 0.8000 - val_loss: 0.6957
# Epoch 210/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9284 - loss: 0.2099 - val_accuracy: 0.8000 - val_loss: 0.6939
# Epoch 211/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9187 - loss: 0.2344 - val_accuracy: 0.8000 - val_loss: 0.6982
# Epoch 212/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8840 - loss: 0.2659 - val_accuracy: 0.8000 - val_loss: 0.7058
# Epoch 213/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9559 - loss: 0.2170 - val_accuracy: 0.8000 - val_loss: 0.7129
# Epoch 214/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9332 - loss: 0.2535 - val_accuracy: 0.8000 - val_loss: 0.7106
# Epoch 215/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8958 - loss: 0.2593 - val_accuracy: 0.8000 - val_loss: 0.7025
# Epoch 216/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9004 - loss: 0.2425 - val_accuracy: 0.8000 - val_loss: 0.7063
# Epoch 217/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9267 - loss: 0.2382 - val_accuracy: 0.8000 - val_loss: 0.7051
# Epoch 218/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9355 - loss: 0.2153 - val_accuracy: 0.8000 - val_loss: 0.6991
# Epoch 219/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9099 - loss: 0.2899 - val_accuracy: 0.8000 - val_loss: 0.7028
# Epoch 220/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8830 - loss: 0.2727 - val_accuracy: 0.8000 - val_loss: 0.6966
# Epoch 221/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9049 - loss: 0.2311 - val_accuracy: 0.7500 - val_loss: 0.7041
# Epoch 222/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9184 - loss: 0.2302 - val_accuracy: 0.7500 - val_loss: 0.7054
# Epoch 223/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9205 - loss: 0.2527 - val_accuracy: 0.8000 - val_loss: 0.7050
# Epoch 224/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9212 - loss: 0.2709 - val_accuracy: 0.8000 - val_loss: 0.6990
# Epoch 225/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9054 - loss: 0.2682 - val_accuracy: 0.8000 - val_loss: 0.6919
# Epoch 226/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9104 - loss: 0.2501 - val_accuracy: 0.8000 - val_loss: 0.6941
# Epoch 227/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9295 - loss: 0.2270 - val_accuracy: 0.8000 - val_loss: 0.6870
# Epoch 228/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9462 - loss: 0.2321 - val_accuracy: 0.8000 - val_loss: 0.6898
# Epoch 229/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9102 - loss: 0.2629 - val_accuracy: 0.8000 - val_loss: 0.7021
# Epoch 230/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9270 - loss: 0.2192 - val_accuracy: 0.7500 - val_loss: 0.7173
# Epoch 231/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9506 - loss: 0.2091 - val_accuracy: 0.8000 - val_loss: 0.7089
# Epoch 232/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8997 - loss: 0.2561 - val_accuracy: 0.8000 - val_loss: 0.7048
# Epoch 233/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9320 - loss: 0.2281 - val_accuracy: 0.8000 - val_loss: 0.6995
# Epoch 234/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9294 - loss: 0.2412 - val_accuracy: 0.8000 - val_loss: 0.7046
# Epoch 235/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8853 - loss: 0.2723 - val_accuracy: 0.8000 - val_loss: 0.7038
# Epoch 236/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9177 - loss: 0.2395 - val_accuracy: 0.8000 - val_loss: 0.7046
# Epoch 237/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9053 - loss: 0.2699 - val_accuracy: 0.8000 - val_loss: 0.7080
# Epoch 238/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9608 - loss: 0.2134 - val_accuracy: 0.8000 - val_loss: 0.6996
# Epoch 239/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9288 - loss: 0.2199 - val_accuracy: 0.8000 - val_loss: 0.7022
# Epoch 240/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9495 - loss: 0.1833 - val_accuracy: 0.8000 - val_loss: 0.7079
# Epoch 241/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9354 - loss: 0.1985 - val_accuracy: 0.8000 - val_loss: 0.6977
# Epoch 242/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9757 - loss: 0.1811 - val_accuracy: 0.8000 - val_loss: 0.6991
# Epoch 243/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9207 - loss: 0.2037 - val_accuracy: 0.8000 - val_loss: 0.7044
# Epoch 244/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9580 - loss: 0.1808 - val_accuracy: 0.8000 - val_loss: 0.7272
# Epoch 245/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9366 - loss: 0.2112 - val_accuracy: 0.8000 - val_loss: 0.7250
# Epoch 246/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9366 - loss: 0.2248 - val_accuracy: 0.8000 - val_loss: 0.7210
# Epoch 247/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9404 - loss: 0.2233 - val_accuracy: 0.8000 - val_loss: 0.7163
# Epoch 248/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9490 - loss: 0.2141 - val_accuracy: 0.8000 - val_loss: 0.7215
# Epoch 249/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9246 - loss: 0.2271 - val_accuracy: 0.8000 - val_loss: 0.7364
# Epoch 250/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9432 - loss: 0.2241 - val_accuracy: 0.8000 - val_loss: 0.7244
# Epoch 251/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9369 - loss: 0.2325 - val_accuracy: 0.8000 - val_loss: 0.7308
# Epoch 252/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9235 - loss: 0.2175 - val_accuracy: 0.8000 - val_loss: 0.7312
# Epoch 253/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9234 - loss: 0.2303 - val_accuracy: 0.8000 - val_loss: 0.7369
# Epoch 254/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9333 - loss: 0.2194 - val_accuracy: 0.8000 - val_loss: 0.7307
# Epoch 255/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9738 - loss: 0.1615 - val_accuracy: 0.8000 - val_loss: 0.7308
# Epoch 256/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9425 - loss: 0.2190 - val_accuracy: 0.8000 - val_loss: 0.7310
# Epoch 257/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9382 - loss: 0.2052 - val_accuracy: 0.8000 - val_loss: 0.7306
# Epoch 258/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9611 - loss: 0.1810 - val_accuracy: 0.8000 - val_loss: 0.7293
# Epoch 259/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9449 - loss: 0.1695 - val_accuracy: 0.8000 - val_loss: 0.7344
# Epoch 260/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9134 - loss: 0.2100 - val_accuracy: 0.8000 - val_loss: 0.7344
# Epoch 261/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9313 - loss: 0.2235 - val_accuracy: 0.8000 - val_loss: 0.7500
# Epoch 262/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8987 - loss: 0.3191 - val_accuracy: 0.8000 - val_loss: 0.7410
# Epoch 263/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9481 - loss: 0.2074 - val_accuracy: 0.8000 - val_loss: 0.7444
# Epoch 264/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9410 - loss: 0.2112 - val_accuracy: 0.8000 - val_loss: 0.7420
# Epoch 265/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9044 - loss: 0.2678 - val_accuracy: 0.8000 - val_loss: 0.7404
# Epoch 266/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9304 - loss: 0.2148 - val_accuracy: 0.8000 - val_loss: 0.7425
# Epoch 267/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9198 - loss: 0.2516 - val_accuracy: 0.8000 - val_loss: 0.7476
# Epoch 268/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9314 - loss: 0.2475 - val_accuracy: 0.8000 - val_loss: 0.7602
# Epoch 269/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9639 - loss: 0.2096 - val_accuracy: 0.8000 - val_loss: 0.7494
# Epoch 270/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9119 - loss: 0.2790 - val_accuracy: 0.8000 - val_loss: 0.7435
# Epoch 271/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9402 - loss: 0.2060 - val_accuracy: 0.8000 - val_loss: 0.7445
# Epoch 272/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9208 - loss: 0.2284 - val_accuracy: 0.8000 - val_loss: 0.7451
# Epoch 273/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9300 - loss: 0.2314 - val_accuracy: 0.8000 - val_loss: 0.7453
# Epoch 274/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9481 - loss: 0.1876 - val_accuracy: 0.8000 - val_loss: 0.7426
# Epoch 275/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9487 - loss: 0.1891 - val_accuracy: 0.8000 - val_loss: 0.7457
# Epoch 276/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9308 - loss: 0.2263 - val_accuracy: 0.8000 - val_loss: 0.7441
# Epoch 277/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9530 - loss: 0.2197 - val_accuracy: 0.8000 - val_loss: 0.7589
# Epoch 278/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9326 - loss: 0.2647 - val_accuracy: 0.8000 - val_loss: 0.7697
# Epoch 279/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9708 - loss: 0.1730 - val_accuracy: 0.8000 - val_loss: 0.7594
# Epoch 280/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9403 - loss: 0.2393 - val_accuracy: 0.8000 - val_loss: 0.7490
# Epoch 281/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9078 - loss: 0.2608 - val_accuracy: 0.8000 - val_loss: 0.7598
# Epoch 282/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9288 - loss: 0.2249 - val_accuracy: 0.8000 - val_loss: 0.7600
# Epoch 283/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9449 - loss: 0.2057 - val_accuracy: 0.8000 - val_loss: 0.7568
# Epoch 284/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9505 - loss: 0.1705 - val_accuracy: 0.8000 - val_loss: 0.7652
# Epoch 285/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9493 - loss: 0.1785 - val_accuracy: 0.8000 - val_loss: 0.7675
# Epoch 286/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9107 - loss: 0.2676 - val_accuracy: 0.8000 - val_loss: 0.7689
# Epoch 287/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9261 - loss: 0.2052 - val_accuracy: 0.8000 - val_loss: 0.7757
# Epoch 288/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9282 - loss: 0.2380 - val_accuracy: 0.8000 - val_loss: 0.7667
# Epoch 289/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9592 - loss: 0.1929 - val_accuracy: 0.8000 - val_loss: 0.7768
# Epoch 290/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9515 - loss: 0.2017 - val_accuracy: 0.8000 - val_loss: 0.7925
# Epoch 291/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9435 - loss: 0.1819 - val_accuracy: 0.8000 - val_loss: 0.7955
# Epoch 292/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9521 - loss: 0.1809 - val_accuracy: 0.8000 - val_loss: 0.7906
# Epoch 293/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9724 - loss: 0.1382 - val_accuracy: 0.8000 - val_loss: 0.7899
# Epoch 294/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9322 - loss: 0.2276 - val_accuracy: 0.8000 - val_loss: 0.7769
# Epoch 295/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9260 - loss: 0.2042 - val_accuracy: 0.8000 - val_loss: 0.7812
# Epoch 296/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9515 - loss: 0.1987 - val_accuracy: 0.8000 - val_loss: 0.7828
# Epoch 297/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9501 - loss: 0.2424 - val_accuracy: 0.8000 - val_loss: 0.7858
# Epoch 298/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9128 - loss: 0.2769 - val_accuracy: 0.8000 - val_loss: 0.7757
# Epoch 299/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9156 - loss: 0.2474 - val_accuracy: 0.8000 - val_loss: 0.7857
# Epoch 300/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9374 - loss: 0.2096 - val_accuracy: 0.8000 - val_loss: 0.7836
# Epoch 301/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9008 - loss: 0.2433 - val_accuracy: 0.8000 - val_loss: 0.7907
# Epoch 302/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9144 - loss: 0.2392 - val_accuracy: 0.8000 - val_loss: 0.7964
# Epoch 303/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9227 - loss: 0.2465 - val_accuracy: 0.8000 - val_loss: 0.7879
# Epoch 304/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9503 - loss: 0.1886 - val_accuracy: 0.7500 - val_loss: 0.8051
# Epoch 305/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9614 - loss: 0.1718 - val_accuracy: 0.7500 - val_loss: 0.8023
# Epoch 306/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9472 - loss: 0.2029 - val_accuracy: 0.7500 - val_loss: 0.7988
# Epoch 307/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9032 - loss: 0.2667 - val_accuracy: 0.7500 - val_loss: 0.8016
# Epoch 308/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9042 - loss: 0.2427 - val_accuracy: 0.7500 - val_loss: 0.8056
# Epoch 309/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9434 - loss: 0.1921 - val_accuracy: 0.7500 - val_loss: 0.8060
# Epoch 310/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9698 - loss: 0.1738 - val_accuracy: 0.7500 - val_loss: 0.7896
# Epoch 311/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9661 - loss: 0.2002 - val_accuracy: 0.7500 - val_loss: 0.7961
# Epoch 312/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9521 - loss: 0.1887 - val_accuracy: 0.7500 - val_loss: 0.8031
# Epoch 313/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9317 - loss: 0.2163 - val_accuracy: 0.7500 - val_loss: 0.7984
# Epoch 314/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9518 - loss: 0.2216 - val_accuracy: 0.7500 - val_loss: 0.7942
# Epoch 315/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9153 - loss: 0.2318 - val_accuracy: 0.7500 - val_loss: 0.7915
# Epoch 316/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9263 - loss: 0.2248 - val_accuracy: 0.7500 - val_loss: 0.7993
# Epoch 317/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9546 - loss: 0.1870 - val_accuracy: 0.7500 - val_loss: 0.8039
# Epoch 318/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9514 - loss: 0.1784 - val_accuracy: 0.7000 - val_loss: 0.8134
# Epoch 319/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9489 - loss: 0.1787 - val_accuracy: 0.7000 - val_loss: 0.8057
# Epoch 320/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9456 - loss: 0.2021 - val_accuracy: 0.7000 - val_loss: 0.8013
# Epoch 321/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9157 - loss: 0.2899 - val_accuracy: 0.7000 - val_loss: 0.7992
# Epoch 322/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9670 - loss: 0.1654 - val_accuracy: 0.7000 - val_loss: 0.8063
# Epoch 323/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9063 - loss: 0.2869 - val_accuracy: 0.7000 - val_loss: 0.8063
# Epoch 324/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9757 - loss: 0.1540 - val_accuracy: 0.7000 - val_loss: 0.8178
# Epoch 325/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9156 - loss: 0.2671 - val_accuracy: 0.7000 - val_loss: 0.8172
# Epoch 326/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9601 - loss: 0.2095 - val_accuracy: 0.7000 - val_loss: 0.8246
# Epoch 327/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9485 - loss: 0.1991 - val_accuracy: 0.7000 - val_loss: 0.8234
# Epoch 328/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9620 - loss: 0.1899 - val_accuracy: 0.7000 - val_loss: 0.8316
# Epoch 329/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9416 - loss: 0.2301 - val_accuracy: 0.7000 - val_loss: 0.8205
# Epoch 330/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9506 - loss: 0.1950 - val_accuracy: 0.7000 - val_loss: 0.8338
# Epoch 331/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9593 - loss: 0.1820 - val_accuracy: 0.7000 - val_loss: 0.8392
# Epoch 332/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9339 - loss: 0.2028 - val_accuracy: 0.7000 - val_loss: 0.8412
# Epoch 333/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9528 - loss: 0.1964 - val_accuracy: 0.7000 - val_loss: 0.8472
# Epoch 334/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9508 - loss: 0.1800 - val_accuracy: 0.7000 - val_loss: 0.8365
# Epoch 335/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9416 - loss: 0.2211 - val_accuracy: 0.7000 - val_loss: 0.8338
# Epoch 336/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9453 - loss: 0.2233 - val_accuracy: 0.7000 - val_loss: 0.8299
# Epoch 337/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9593 - loss: 0.1743 - val_accuracy: 0.7000 - val_loss: 0.8296
# Epoch 338/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9667 - loss: 0.1900 - val_accuracy: 0.7000 - val_loss: 0.8388
# Epoch 339/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9546 - loss: 0.1885 - val_accuracy: 0.7000 - val_loss: 0.8322
# Epoch 340/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9444 - loss: 0.2154 - val_accuracy: 0.7000 - val_loss: 0.8388
# Epoch 341/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9295 - loss: 0.1941 - val_accuracy: 0.7000 - val_loss: 0.8391
# Epoch 342/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9676 - loss: 0.1577 - val_accuracy: 0.7000 - val_loss: 0.8279
# Epoch 343/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9448 - loss: 0.1913 - val_accuracy: 0.7000 - val_loss: 0.8402
# Epoch 344/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9328 - loss: 0.2050 - val_accuracy: 0.7000 - val_loss: 0.8313
# Epoch 345/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9695 - loss: 0.1685 - val_accuracy: 0.7000 - val_loss: 0.8311
# Epoch 346/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9711 - loss: 0.1703 - val_accuracy: 0.7000 - val_loss: 0.8365
# Epoch 347/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9361 - loss: 0.2100 - val_accuracy: 0.7000 - val_loss: 0.8411
# Epoch 348/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9231 - loss: 0.2114 - val_accuracy: 0.7000 - val_loss: 0.8475
# Epoch 349/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9388 - loss: 0.1914 - val_accuracy: 0.7000 - val_loss: 0.8368
# Epoch 350/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9333 - loss: 0.1893 - val_accuracy: 0.7000 - val_loss: 0.8354
# Epoch 351/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9612 - loss: 0.1742 - val_accuracy: 0.7000 - val_loss: 0.8370
# Epoch 352/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9816 - loss: 0.1441 - val_accuracy: 0.7000 - val_loss: 0.8402
# Epoch 353/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9367 - loss: 0.2136 - val_accuracy: 0.7000 - val_loss: 0.8363
# Epoch 354/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9605 - loss: 0.1874 - val_accuracy: 0.7000 - val_loss: 0.8357
# Epoch 355/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9564 - loss: 0.1756 - val_accuracy: 0.7000 - val_loss: 0.8420
# Epoch 356/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9633 - loss: 0.1656 - val_accuracy: 0.7000 - val_loss: 0.8483
# Epoch 357/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9551 - loss: 0.2275 - val_accuracy: 0.7000 - val_loss: 0.8493
# Epoch 358/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9649 - loss: 0.1681 - val_accuracy: 0.7000 - val_loss: 0.8658
# Epoch 359/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9612 - loss: 0.1496 - val_accuracy: 0.7000 - val_loss: 0.8624
# Epoch 360/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9463 - loss: 0.1735 - val_accuracy: 0.7000 - val_loss: 0.8689
# Epoch 361/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9595 - loss: 0.1736 - val_accuracy: 0.7000 - val_loss: 0.8494
# Epoch 362/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9326 - loss: 0.2375 - val_accuracy: 0.7000 - val_loss: 0.8408
# Epoch 363/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9389 - loss: 0.1869 - val_accuracy: 0.7000 - val_loss: 0.8646
# Epoch 364/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9445 - loss: 0.1942 - val_accuracy: 0.7000 - val_loss: 0.8667
# Epoch 365/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9562 - loss: 0.1905 - val_accuracy: 0.7000 - val_loss: 0.8509
# Epoch 366/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9435 - loss: 0.2007 - val_accuracy: 0.7000 - val_loss: 0.8525
# Epoch 367/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9736 - loss: 0.1931 - val_accuracy: 0.7000 - val_loss: 0.8523
# Epoch 368/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9388 - loss: 0.2037 - val_accuracy: 0.7000 - val_loss: 0.8535
# Epoch 369/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9789 - loss: 0.1574 - val_accuracy: 0.7000 - val_loss: 0.8590
# Epoch 370/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9499 - loss: 0.1731 - val_accuracy: 0.7000 - val_loss: 0.8485
# Epoch 371/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9240 - loss: 0.2139 - val_accuracy: 0.7000 - val_loss: 0.8762
# Epoch 372/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9228 - loss: 0.2496 - val_accuracy: 0.7000 - val_loss: 0.8638
# Epoch 373/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9262 - loss: 0.2491 - val_accuracy: 0.7000 - val_loss: 0.8624
# Epoch 374/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9403 - loss: 0.2568 - val_accuracy: 0.7000 - val_loss: 0.8657
# Epoch 375/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9274 - loss: 0.2563 - val_accuracy: 0.7000 - val_loss: 0.8659
# ...
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9551 - loss: 0.2194 - val_accuracy: 0.7000 - val_loss: 0.9105
# Epoch 477/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9612 - loss: 0.1525 - val_accuracy: 0.7000 - val_loss: 0.9106
# Epoch 478/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9566 - loss: 0.1597 - val_accuracy: 0.7000 - val_loss: 0.9235
# Epoch 479/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9782 - loss: 0.1278 - val_accuracy: 0.7000 - val_loss: 0.9132
# Epoch 480/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9339 - loss: 0.1892 - val_accuracy: 0.7000 - val_loss: 0.9339
# Epoch 481/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9679 - loss: 0.1422 - val_accuracy: 0.7000 - val_loss: 0.9319
# Epoch 482/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9404 - loss: 0.1576 - val_accuracy: 0.7000 - val_loss: 0.9199
# Epoch 483/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9639 - loss: 0.1303 - val_accuracy: 0.7000 - val_loss: 0.9231
# Epoch 484/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9157 - loss: 0.2822 - val_accuracy: 0.7000 - val_loss: 0.9271
# Epoch 485/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9539 - loss: 0.1591 - val_accuracy: 0.7000 - val_loss: 0.9064
# Epoch 486/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9776 - loss: 0.1585 - val_accuracy: 0.7000 - val_loss: 0.9190
# Epoch 487/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9394 - loss: 0.2037 - val_accuracy: 0.7000 - val_loss: 0.9229
# Epoch 488/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9428 - loss: 0.1977 - val_accuracy: 0.7000 - val_loss: 0.9038
# Epoch 489/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9732 - loss: 0.1234 - val_accuracy: 0.7000 - val_loss: 0.9144
# Epoch 490/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9589 - loss: 0.1702 - val_accuracy: 0.7000 - val_loss: 0.9241
# Epoch 491/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9564 - loss: 0.1843 - val_accuracy: 0.7000 - val_loss: 0.9202
# Epoch 492/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9766 - loss: 0.1369 - val_accuracy: 0.7000 - val_loss: 0.9281
# Epoch 493/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9505 - loss: 0.1902 - val_accuracy: 0.7000 - val_loss: 0.9145
# Epoch 494/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9443 - loss: 0.1770 - val_accuracy: 0.7000 - val_loss: 0.9177
# Epoch 495/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9540 - loss: 0.1887 - val_accuracy: 0.7000 - val_loss: 0.9233
# Epoch 496/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9406 - loss: 0.1738 - val_accuracy: 0.7000 - val_loss: 0.9167
# Epoch 497/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9499 - loss: 0.1873 - val_accuracy: 0.7000 - val_loss: 0.9102
# Epoch 498/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9707 - loss: 0.1714 - val_accuracy: 0.7000 - val_loss: 0.9333
# Epoch 499/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9494 - loss: 0.1693 - val_accuracy: 0.7000 - val_loss: 0.9341
# Epoch 500/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9214 - loss: 0.1984 - val_accuracy: 0.7000 - val_loss: 0.9210
# Epoch 501/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9337 - loss: 0.2002 - val_accuracy: 0.7000 - val_loss: 0.9249
# Epoch 502/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9543 - loss: 0.1909 - val_accuracy: 0.7000 - val_loss: 0.9111
# Epoch 503/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9329 - loss: 0.2358 - val_accuracy: 0.7000 - val_loss: 0.9189
# Epoch 504/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9607 - loss: 0.1565 - val_accuracy: 0.7000 - val_loss: 0.9400
# Epoch 505/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9752 - loss: 0.1375 - val_accuracy: 0.7000 - val_loss: 0.9346
# Epoch 506/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9577 - loss: 0.1422 - val_accuracy: 0.7000 - val_loss: 0.9368
# Epoch 507/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9479 - loss: 0.1453 - val_accuracy: 0.7000 - val_loss: 0.9559
# Epoch 508/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9375 - loss: 0.2217 - val_accuracy: 0.7000 - val_loss: 0.9249
# Epoch 509/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9221 - loss: 0.1993 - val_accuracy: 0.7000 - val_loss: 0.9264
# Epoch 510/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9763 - loss: 0.1540 - val_accuracy: 0.7000 - val_loss: 0.9298
# Epoch 511/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9413 - loss: 0.1858 - val_accuracy: 0.7000 - val_loss: 0.9600
# Epoch 512/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9689 - loss: 0.1616 - val_accuracy: 0.7000 - val_loss: 0.9311
# Epoch 513/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9577 - loss: 0.2035 - val_accuracy: 0.7000 - val_loss: 0.9205
# Epoch 514/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9276 - loss: 0.2215 - val_accuracy: 0.7000 - val_loss: 0.9268
# Epoch 515/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9596 - loss: 0.1726 - val_accuracy: 0.7000 - val_loss: 0.9238
# Epoch 516/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9490 - loss: 0.1904 - val_accuracy: 0.7000 - val_loss: 0.9441
# Epoch 517/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9342 - loss: 0.1992 - val_accuracy: 0.7000 - val_loss: 0.9524
# Epoch 518/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9732 - loss: 0.1581 - val_accuracy: 0.7000 - val_loss: 0.9381
# Epoch 519/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9484 - loss: 0.1818 - val_accuracy: 0.7000 - val_loss: 0.9276
# Epoch 520/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9367 - loss: 0.1858 - val_accuracy: 0.7000 - val_loss: 0.9420
# Epoch 521/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9549 - loss: 0.1436 - val_accuracy: 0.7000 - val_loss: 0.9455
# Epoch 522/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9345 - loss: 0.1749 - val_accuracy: 0.7000 - val_loss: 0.9399
# Epoch 523/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9854 - loss: 0.1272 - val_accuracy: 0.7000 - val_loss: 0.9396
# Epoch 524/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9615 - loss: 0.1341 - val_accuracy: 0.7000 - val_loss: 0.9505
# Epoch 525/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9226 - loss: 0.1761 - val_accuracy: 0.7000 - val_loss: 0.9377
# Epoch 526/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9239 - loss: 0.2141 - val_accuracy: 0.7000 - val_loss: 0.9386
# Epoch 527/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9385 - loss: 0.1622 - val_accuracy: 0.7000 - val_loss: 0.9469
# Epoch 528/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9110 - loss: 0.2580 - val_accuracy: 0.7000 - val_loss: 0.9544
# Epoch 529/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9008 - loss: 0.2062 - val_accuracy: 0.7000 - val_loss: 0.9432
# Epoch 530/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9528 - loss: 0.1542 - val_accuracy: 0.7000 - val_loss: 0.9530
# Epoch 531/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9472 - loss: 0.1599 - val_accuracy: 0.7000 - val_loss: 0.9531
# Epoch 532/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9137 - loss: 0.2043 - val_accuracy: 0.7000 - val_loss: 0.9659
# Epoch 533/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9387 - loss: 0.1880 - val_accuracy: 0.7000 - val_loss: 0.9592
# Epoch 534/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9472 - loss: 0.1512 - val_accuracy: 0.7000 - val_loss: 0.9692
# Epoch 535/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9551 - loss: 0.1413 - val_accuracy: 0.7000 - val_loss: 0.9535
# Epoch 536/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9618 - loss: 0.1458 - val_accuracy: 0.7000 - val_loss: 0.9342
# Epoch 537/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9160 - loss: 0.2679 - val_accuracy: 0.7000 - val_loss: 0.9383
# Epoch 538/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9206 - loss: 0.2321 - val_accuracy: 0.7000 - val_loss: 0.9555
# Epoch 539/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9289 - loss: 0.2471 - val_accuracy: 0.7000 - val_loss: 0.9340
# Epoch 540/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9804 - loss: 0.1485 - val_accuracy: 0.7000 - val_loss: 0.9372
# Epoch 541/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9160 - loss: 0.1727 - val_accuracy: 0.7000 - val_loss: 0.9510
# Epoch 542/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9577 - loss: 0.1631 - val_accuracy: 0.7000 - val_loss: 0.9394
# Epoch 543/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9226 - loss: 0.2460 - val_accuracy: 0.7000 - val_loss: 0.9292
# Epoch 544/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9626 - loss: 0.1673 - val_accuracy: 0.7000 - val_loss: 0.9468
# Epoch 545/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9366 - loss: 0.1741 - val_accuracy: 0.7000 - val_loss: 0.9582
# Epoch 546/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9401 - loss: 0.1763 - val_accuracy: 0.7000 - val_loss: 0.9462
# Epoch 547/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9363 - loss: 0.2201 - val_accuracy: 0.7000 - val_loss: 0.9314
# Epoch 548/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9289 - loss: 0.2182 - val_accuracy: 0.7000 - val_loss: 0.9505
# Epoch 549/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9532 - loss: 0.1506 - val_accuracy: 0.7000 - val_loss: 0.9617
# Epoch 550/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8952 - loss: 0.2374 - val_accuracy: 0.7000 - val_loss: 0.9662
# Epoch 551/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9276 - loss: 0.2167 - val_accuracy: 0.7000 - val_loss: 0.9489
# Epoch 552/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9153 - loss: 0.1825 - val_accuracy: 0.7000 - val_loss: 0.9551
# Epoch 553/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9596 - loss: 0.1306 - val_accuracy: 0.7000 - val_loss: 0.9346
# Epoch 554/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9686 - loss: 0.1314 - val_accuracy: 0.7000 - val_loss: 0.9405
# Epoch 555/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9608 - loss: 0.1375 - val_accuracy: 0.7000 - val_loss: 0.9504
# Epoch 556/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9289 - loss: 0.1981 - val_accuracy: 0.7000 - val_loss: 0.9449
# Epoch 557/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8847 - loss: 0.2797 - val_accuracy: 0.7000 - val_loss: 0.9410
# Epoch 558/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9716 - loss: 0.1045 - val_accuracy: 0.7000 - val_loss: 0.9581
# Epoch 559/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9240 - loss: 0.1928 - val_accuracy: 0.7000 - val_loss: 0.9714
# Epoch 560/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9679 - loss: 0.1270 - val_accuracy: 0.7000 - val_loss: 0.9577
# Epoch 561/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9406 - loss: 0.1762 - val_accuracy: 0.7000 - val_loss: 0.9361
# Epoch 562/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9385 - loss: 0.1848 - val_accuracy: 0.7000 - val_loss: 0.9415
# Epoch 563/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9416 - loss: 0.1475 - val_accuracy: 0.7000 - val_loss: 0.9571
# Epoch 564/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9548 - loss: 0.1609 - val_accuracy: 0.7000 - val_loss: 0.9702
# Epoch 565/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9511 - loss: 0.1666 - val_accuracy: 0.7000 - val_loss: 0.9609
# Epoch 566/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9301 - loss: 0.1781 - val_accuracy: 0.7000 - val_loss: 0.9572
# Epoch 567/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9348 - loss: 0.1723 - val_accuracy: 0.7000 - val_loss: 0.9517
# Epoch 568/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9515 - loss: 0.1794 - val_accuracy: 0.7000 - val_loss: 0.9475
# Epoch 569/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9203 - loss: 0.2030 - val_accuracy: 0.7000 - val_loss: 0.9692
# Epoch 570/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9382 - loss: 0.1952 - val_accuracy: 0.7000 - val_loss: 0.9555
# Epoch 571/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9387 - loss: 0.1732 - val_accuracy: 0.7000 - val_loss: 0.9478
# Epoch 572/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9444 - loss: 0.2104 - val_accuracy: 0.7000 - val_loss: 0.9407
# Epoch 573/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9289 - loss: 0.1904 - val_accuracy: 0.7000 - val_loss: 0.9518
# Epoch 574/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9276 - loss: 0.1746 - val_accuracy: 0.7000 - val_loss: 0.9604
# Epoch 575/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9452 - loss: 0.1673 - val_accuracy: 0.7000 - val_loss: 0.9562
# Epoch 576/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9361 - loss: 0.1669 - val_accuracy: 0.7000 - val_loss: 0.9695
# Epoch 577/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9583 - loss: 0.1374 - val_accuracy: 0.7000 - val_loss: 0.9539
# Epoch 578/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9596 - loss: 0.1465 - val_accuracy: 0.7000 - val_loss: 0.9663
# Epoch 579/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9642 - loss: 0.1539 - val_accuracy: 0.7000 - val_loss: 0.9531
# Epoch 580/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9329 - loss: 0.1625 - val_accuracy: 0.7000 - val_loss: 0.9804
# Epoch 581/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9361 - loss: 0.1679 - val_accuracy: 0.7000 - val_loss: 0.9683
# Epoch 582/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9296 - loss: 0.2382 - val_accuracy: 0.7000 - val_loss: 0.9668
# Epoch 583/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9452 - loss: 0.1395 - val_accuracy: 0.7000 - val_loss: 0.9664
# Epoch 584/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9258 - loss: 0.2223 - val_accuracy: 0.7000 - val_loss: 0.9658
# Epoch 585/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9283 - loss: 0.1816 - val_accuracy: 0.7000 - val_loss: 0.9732
# Epoch 586/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8952 - loss: 0.2726 - val_accuracy: 0.7000 - val_loss: 0.9681
# Epoch 587/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9291 - loss: 0.2193 - val_accuracy: 0.7000 - val_loss: 0.9529
# Epoch 588/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9422 - loss: 0.2205 - val_accuracy: 0.7000 - val_loss: 0.9549
# Epoch 589/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9602 - loss: 0.1417 - val_accuracy: 0.7000 - val_loss: 0.9668
# Epoch 590/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9317 - loss: 0.2069 - val_accuracy: 0.7000 - val_loss: 0.9552
# Epoch 591/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9274 - loss: 0.1844 - val_accuracy: 0.7000 - val_loss: 0.9598
# Epoch 592/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9661 - loss: 0.1201 - val_accuracy: 0.7000 - val_loss: 0.9668
# Epoch 593/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9581 - loss: 0.1930 - val_accuracy: 0.7000 - val_loss: 0.9621
# Epoch 594/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9511 - loss: 0.1737 - val_accuracy: 0.7000 - val_loss: 0.9672
# Epoch 595/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9502 - loss: 0.1564 - val_accuracy: 0.7000 - val_loss: 0.9527
# Epoch 596/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9248 - loss: 0.2377 - val_accuracy: 0.7000 - val_loss: 0.9528
# Epoch 597/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9542 - loss: 0.1568 - val_accuracy: 0.7000 - val_loss: 0.9559
# Epoch 598/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9277 - loss: 0.2188 - val_accuracy: 0.7000 - val_loss: 0.9631
# Epoch 599/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9240 - loss: 0.2020 - val_accuracy: 0.7000 - val_loss: 0.9618
# Epoch 600/600
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9211 - loss: 0.1844 - val_accuracy: 0.7000 - val_loss: 0.9756
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Training error: 11.00%, Test error: 16.00%

# %% [markdown]
# #### Plot the results from the model

# %%
# With this function you can plot the history of the model training produced by the fit function
def plot_history(history):
    fig, ax = plt.subplots()
    # Plot training & validation accuracy values
    ax.plot(history.history['accuracy'], label='Train')
    ax.plot(history.history['val_accuracy'], label='Val')
    ax.set_title('Model accuracy')
    ax.set_ylabel('Accuracy')
    ax.set_xlabel('Epoch')
    ax.legend(loc='best')
    return fig, ax

# %%
fig, ax = separatingFLR(Xtr, Ytr, train_preds, model)
ax.set_title("Predicted class seperation");
fig, ax = plot_history(history)
ax.set_title("Accuracy evolution over epochs");
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## Exploring Different Architectures
#
# Using a simple binary classification dataset you will build a keras model with Dense layers, and the RELU activation function.
#
# You will explore different architectures to try and see when the NN overfits or underfits the data.
#
# In particular, you should try the following:
#  1. A NN with a single hidden layer with many (e.g. 100) neurons
#  2. A NN with many (e.g. 3, 4, 5) hidden layers with a few neurons (e.g. 10 to 30).
#
# Train the neural network using the SGD algorithm with a learning rate of 0.05 (you may explore different values) for 500 epochs (or less if time doesn't permit).
#
# For each setting you try, plot the training and validation errors as a function of the epochs, and plot the separating function (use the `separatingFLR` function).
#
# For each setting comment on whether the NN is overfitting or not. Further comment on which model you believe is better, and why (e.g. computational or accuracy considerations).
#
# We provide some skeleton code to train and evaluate a model, you'll have to fill it in, and do the same thing multiple times for different models.

# %% [markdown]
# #### 1) NN with single layer with 100 neurons

# %%
# Build your first model by creating a Sequential object and then adding 3 Dense layers:
model = Sequential()

# Add layers
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))

model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.05),
    loss='binary_crossentropy',
    metrics=['accuracy'],
)

# Fit model
history = model.fit(
    Xtr, Ytr,
    epochs=500,
    batch_size=10,
    validation_split=0.2,
)

# Predict and calculate errors
train_preds = model.predict(Xtr)
test_preds = model.predict(Xte)
train_err = calc_err(train_preds, Ytr)
test_err = calc_err(test_preds, Yte)
print("Training error: %.2f%%, Test error: %.2f%%" % (train_err * 100, test_err * 100))

fig, ax = separatingFLR(Xtr, Ytr, train_preds, model)
ax.set_title("Predicted class seperation");
fig, ax = plot_history(history)
ax.set_title("Accuracy evolution over epochs");
# Out:
# Epoch 1/500
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-6797144a37f1> in <cell line: 16>()
#      14
#      15 # Fit model
# ---> 16 history = model.fit(
#      17     Xtr, Ytr,
#      18     epochs=500,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/nn.py in binary_crossentropy(target, output, from_logits)
#     692
#     693     if len(target.shape) != len(output.shape):
# --> 694         raise ValueError(
#     695             "Arguments `target` and `output` must have the same rank "
#     696             "(ndim). Received: "
#
# ValueError: Arguments `target` and `output` must have the same rank (ndim). Received: target.shape=(10,), output.shape=(10, 100)

# %%
# Plot separating function

# %% [markdown]
# #### 2) NN with 4 hidden layer with  40 neurons

# %%
# Repeat the previous code but with 4 hidden layers with 40 neurons (in each layer)

# %%
# Plot separating function

# %% [markdown]
# ## [Optional] Train a Neural Network on MNIST!
#
# We can finally switch to a real dataset now.
#
# First we will load the MNIST dataset and plot it to see how it really looks like.
#
# Then we will use the notions learned in the first part to train a model which can distinguish two digits in the MNIST data.

# %% [markdown]
# ## Load Data

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
print("Training set shapes: ", x_train.shape, y_train.shape)
print("Test set shapes: ", x_test.shape, y_test.shape)

# %% [markdown]
# #### Bring the data into shape
#
# 1. Choose the digits we want to classify (variables `num_1` and `num_2`)
# 2. Then we restrict training and test sets to only use those numbers
# 3. We reshape the images from 28*28 to a single 784-dimensional vector
# 4. Finally we modify the labels to their appropriate range (0 and +1)

# %%
# Pick two digits, later you can try with different pairs
num_1 = 1
num_2 = 7

# Here we take only two digits from MNIST.
# We will reduce the problem to binary classification.
Xtr = x_train[(y_train == num_1) | (y_train == num_2)]
Ytr = y_train[(y_train == num_1) | (y_train == num_2)]
Xts = x_test[(y_test == num_1) | (y_test == num_2)]
Yts = y_test[(y_test == num_1) | (y_test == num_2)]

# Reshape the data correctly
Xtr = Xtr.reshape(-1, 28*28)
Xts = Xts.reshape(-1, 28*28)
Ytr[Ytr == num_1] = 0
Ytr[Ytr == num_2] = 1
Yts[Yts == num_1] = 0
Yts[Yts == num_2] = 1

# %% [markdown]
# We can visualize the images...

# %%
fig, ax = plt.subplots()
ax.imshow(Xtr[3].reshape(28, 28))
ax.set_title(Ytr[3]);

# %% [markdown]
# #### Define The Keras Model
#
# Here you can play with the structure of the network, e.g. you may start from dense layers and then check what happens if you replace them with convolutional layers

# %%
model = Sequential()
# Add hidden layers
...
# This is the last layer, it should have 1 neuron and the sigmoid activation
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# #### Compile The Keras Model
#
# Here we will use the Adam optimizer instead. It tends to work better than SGD with high dimensional data (such as our MNIST images).

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=['accuracy'],)

# %% [markdown]
# #### Fit the model

# %%
# fit the keras model on the dataset

# %%
# Predict and calculate errors

# %%
# evaluate the keras model. Is this consistent with the error you computed above?
_, accuracy = model.evaluate(Xts, Yts)
print('Test accuracy: %.2f%%' % (accuracy*100))

# %%
# Plot training history
